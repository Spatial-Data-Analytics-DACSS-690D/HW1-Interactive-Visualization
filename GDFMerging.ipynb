# %% [markdown]
# # Merging DF into a GDF
#
# We will need these two inputs:
#
# 1. The GDF:

# %%
import geopandas as gpd

linkGit='https://github.com/Spatial-Data-Analytics-DACSS-690D/HW1-Interactive-Visualization/raw/refs/heads/main/'
linkWorldMaps='WORLD/worldMaps.gpkg'
countries=gpd.read_file(linkGit+linkWorldMaps,layer='countries')

# %% [markdown]
# 2. The DF

# %%
import pandas as pd

someDataLink='WORLD/some_dataworld.csv'

someData=pd.read_csv(linkGit+someDataLink)

# %% [markdown]
# MERGING  is a critical preprocessing operation, as it is in charge of combining data sets, in this case combine a DF into a GDF. Some requisites must be met:
#
# * There is at least one common column needed to serve for the matches.
# * The common columns, or KEYs, need contents to be written exactly in both columns.
# * It is recommended that both KEYs are named the same.
#
# Here we have the KEYs:

# %%
countries.COUNTRY.head()
# Out:
# 0    Aruba (Netherlands)
# 1    Antigua and Barbuda
# 2            Afghanistan
# 3                Algeria
# 4             Azerbaijan
# Name: COUNTRY, dtype: object

# %%
someData.Country.head()
# Out:
# 0            AFGHANISTAN
# 1                ALBANIA
# 2                ALGERIA
# 3                 ANGOLA
# 4    ANTIGUA AND BARBUDA
# Name: Country, dtype: object

# %% [markdown]
# Let's solve the _country name_ differences for the KEYs:

# %%
countries.rename(columns={'COUNTRY':'Country'},inplace=True)

# %% [markdown]
# We can notice the different *case* in the KEYs. Let's work with uppercases:

# %%
countries['Country']=countries.Country.str.upper()

# %% [markdown]
# We could try the merge now?

# %%
countries.merge(someData)
# Out:
#                  Country                                           geometry  \
# 0    ANTIGUA AND BARBUDA  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 1            AFGHANISTAN  MULTIPOLYGON (((61.27656 35.60725, 61.29638 35...
# 2                ALGERIA  MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# 3             AZERBAIJAN  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# 4                ALBANIA  MULTIPOLYGON (((20.79192 40.43154, 20.78722 40...
# ..                   ...                                                ...
# 137                YEMEN  MULTIPOLYGON (((48.68639 14.0375, 48.61 14.044...
# 138               ZAMBIA  MULTIPOLYGON (((30.21302 -14.98172, 30.21917 -...
# 139             ZIMBABWE  MULTIPOLYGON (((32.48888 -21.34445, 32.46541 -...
# 140          SOUTH SUDAN  MULTIPOLYGON (((34.21807 9.96458, 34.20722 9.9...
# 141            INDONESIA  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
#
#     iso2 iso3                             region  fragility        co2  \
# 0     AG  ATG  CENTRAL AMERICA AND THE CARIBBEAN       54.4     729000
# 1     AF  AFG                         SOUTH ASIA      105.0    7893000
# 2     DZ  DZA                             AFRICA       75.4  151633000
# 3     AZ  AZE                        MIDDLE EAST       73.2   35389000
# 4     AL  ALB                             EUROPE       58.9    3794000
# ..   ...  ...                                ...        ...        ...
# 137   YE  YEM                        MIDDLE EAST      113.5   10158000
# 138   ZM  ZMB                             AFRICA       85.7    6798000
# 139   ZW  ZWE                             AFRICA       99.5    7902000
# 140   SS  SSD                             AFRICA      112.2    1778000
# 141   ID  IDN            EAST AND SOUTHEAST ASIA       70.4  563543000
#
#        sq_km  num_airports  population    mobiles
# 0        443             4      102634     184000
# 1     652230            68    40121552   23000000
# 2    2381740            95    47022473   51500000
# 3      86600            32    10650239   11000000
# 4      28748             3     3107100    2610000
# ..       ...           ...         ...        ...
# 137   527968            37    32140443   20000000
# 138   752618           120    20799116   21200000
# 139   390757           144    17150352   15000000
# 140   644329            89    12703714    6170000
# 141  1904569           556   281562465  352000000
#
# [142 rows x 11 columns]

# %% [markdown]
# This merge would create a new map, but this one has much less rows. Our guess is that there are more countries in common, but written slightly different.
#
#  Let's verify this guess:

# %%
onlyDF=set(someData.Country)- set(countries.Country)
onlyGDF=set(countries.Country)- set(someData.Country)

# %% [markdown]
# Check here:

# %%
onlyDF # they did not find a match in the MAP GDF!
# Out:
# {'BAHAMAS (THE)',
#  'BOLIVIA (PLURINATIONAL STATE OF)',
#  'BRUNEI DARUSSALAM',
#  'CABO VERDE',
#  'CENTRAL AFRICAN REPUBLIC (THE)',
#  'COMOROS (THE)',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#  'CONGO (THE)',
#  "CÔTE D'IVOIRE",
#  'DOMINICAN REPUBLIC (THE)',
#  'ESWATINI',
#  'GAMBIA (THE)',
#  'IRAN (ISLAMIC REPUBLIC OF)',
#  'KOREA (THE REPUBLIC OF)',
#  "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
#  'MICRONESIA (FEDERATED STATES OF)',
#  'MOLDOVA (THE REPUBLIC OF)',
#  'NETHERLANDS (THE)',
#  'NIGER (THE)',
#  'NORTH MACEDONIA',
#  'NORTHERN MARIANA ISLANDS (THE)',
#  'PHILIPPINES (THE)',
#  'RUSSIAN FEDERATION (THE)',
#  'SAMOA',
#  'SUDAN (THE)',
#  'TANZANIA, THE UNITED REPUBLIC OF',
#  'TIMOR-LESTE',
#  'UNITED ARAB EMIRATES (THE)',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#  'UNITED STATES OF AMERICA (THE)'}

# %%
onlyGDF # they did not find a match in the DF!
# Out:
# {'AMERICAN SAMOA (US)',
#  'AMERICAN VIRGIN ISLANDS (US)',
#  'ANDORRA',
#  'ANGUILLA (UK)',
#  'ANTARCTICA',
#  'ARUBA (NETHERLANDS)',
#  'BAHAMAS',
#  'BAKER ISLAND (US)',
#  'BERMUDA (UK)',
#  'BOLIVIA',
#  'BONAIRE (NETHERLANDS)',
#  'BOUVET ISLAND (NORWAY)',
#  'BRITISH INDIAN OCEAN TERRITORY (UK)',
#  'BRITISH VIRGIN ISLANDS(UK)',
#  'BRUNEI',
#  'CAPE VERDE',
#  'CAYMAN ISLANDS (UK)',
#  'CENTRAL AFRICAN REPUBLIC',
#  'CHRISTMAS ISLAND (AUSTRALIA)',
#  'COCOS (KEELING) ISLANDS (AUSTRALIA)',
#  'COMOROS',
#  'CONGO',
#  'COOK ISLANDS (NEW ZEALAND)',
#  'CURACAO (NETHERLANDS)',
#  'CZECH REPUBLIC',
#  'DEMOCRATIC REPUBLIC OF THE CONGO',
#  'DOMINICA',
#  'DOMINICAN REPUBLIC',
#  'EAST TIMOR',
#  'ERITREA',
#  'FALKLAND ISLANDS (UK)',
#  'FAROE ISLANDS (DENMARK)',
#  'FEDERATED STATES OF MICRONESIA',
#  'FRENCH GUIANA (FRANCE)',
#  'FRENCH POLYNESIA (FRANCE)',
#  'FRENCH SOUTHERN & ANTARCTIC LANDS (FRANCE)',
#  'GAMBIA',
#  'GIBRALTAR (UK)',
#  'GLORIOSO ISLANDS (FRANCE)',
#  'GREENLAND (DENMARK)',
#  'GUADELOUPE (FRANCE)',
#  'GUAM (US)',
#  'GUERNSEY (UK)',
#  'HEARD ISLAND & MCDONALD ISLANDS (AUSTRALIA)',
#  'HOWLAND ISLAND (US)',
#  'IRAN',
#  'ISLE OF MAN (UK)',
#  'IVORY COAST',
#  'JAN MAYEN (NORWAY)',
#  'JARVIS ISLAND (US)',
#  'JERSEY (UK)',
#  'JOHNSTON ATOLL (US)',
#  'JUAN DE NOVA ISLAND (FRANCE)',
#  'KIRIBATI',
#  'LAOS',
#  'LIECHTENSTEIN',
#  'MACEDONIA',
#  'MARSHALL ISLANDS',
#  'MARTINIQUE (FRANCE)',
#  'MAYOTTE (FRANCE)',
#  'MIDWAY ISLANDS (US)',
#  'MOLDOVA',
#  'MONACO',
#  'MONTSERRAT (UK)',
#  'MYANMAR',
#  'NAURU',
#  'NETHERLANDS',
#  'NEW CALEDONIA (FRANCE)',
#  'NIGER',
#  'NIUE (NEW ZEALAND)',
#  'NORFOLK ISLAND (AUSTRALIA)',
#  'NORTH KOREA',
#  'NORTHERN MARIANA ISLANDS (US)',
#  'PALAU (US)',
#  'PALESTINE',
#  'PARACEL ISLANDS (CHINA)',
#  'PHILIPPINES',
#  'PITCAIRN ISLANDS (UK)',
#  'PUERTO RICO (US)',
#  'REUNION (FRANCE)',
#  'RUSSIA',
#  'SAN MARINO',
#  'SLOVAKIA',
#  'SOMALIA',
#  'SOUTH GEORGIA AND THE SOUTH SANDWICH IS (UK)',
#  'SOUTH KOREA',
#  'SPRATLY ISLANDS (DISPUTED)',
#  'ST. HELENA (UK)',
#  'ST. KITTS AND NEVIS',
#  'ST. LUCIA',
#  'ST. PIERRE AND MIQUELON (FRANCE)',
#  'ST. VINCENT AND THE GRENADINES',
#  'SUDAN',
#  'SVALBARD (NORWAY)',
#  'SWAZILAND',
#  'SYRIA',
#  'TAIWAN',
#  'TANZANIA',
#  'TOKELAU (NEW ZEALAND)',
#  'TONGA',
#  'TURKS AND CAICOS ISLANDS (UK)',
#  'TUVALU',
#  'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM',
#  'UNITED STATES',
#  'VANUATU',
#  'WAKE ISLAND (US)',
#  'WALLIS AND FUTUNA (FRANCE)',
#  'WESTERN SAHARA',
#  'WESTERN SAMOA'}

# %% [markdown]
# The job now is to match the pair of countries that are written differently. This is called fuzzy merging.

# %% [markdown]
# ### Fuzzy merging

# %% [markdown]
# We use this technique to detect similarities between strings. You need this package **thefuzz** (based on the [Levenshtein algorithm](https://en.wikipedia.org/wiki/Levenshtein_distance)):

# %%
# !pip install thefuzz
# Out:
# Requirement already satisfied: thefuzz in /usr/local/lib/python3.12/dist-packages (0.22.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from thefuzz) (3.14.1)

# %% [markdown]
# This is the basic idea:

# %%
from thefuzz.process import extractOne as best

## find the BEST match to 'BAHAMAS (THE)'
## from all strings in 'onlyGDF'

best('BAHAMAS (THE)',onlyGDF)
# Out:
# ('BAHAMAS', 90)

# %% [markdown]
# As you see, you get a coefficient value of 90 (the closer to 100 the better). That may be a reliable result.
#
# Let's do the same for all the unmatched countries:

# %%
## for each country in onlyDF, find the BEST match in onlyGDF

[(country, best(country,onlyGDF)) for country in onlyDF]
# Out:
# [('BAHAMAS (THE)', ('BAHAMAS', 90)),
#  ('BOLIVIA (PLURINATIONAL STATE OF)', ('BOLIVIA', 90)),
#  ('UNITED ARAB EMIRATES (THE)', ('UNITED ARAB EMIRATES', 95)),
#  ('RUSSIAN FEDERATION (THE)', ('RUSSIA', 90)),
#  ('ESWATINI', ('MARTINIQUE (FRANCE)', 60)),
#  ('NORTH MACEDONIA', ('MACEDONIA', 90)),
#  ('NETHERLANDS (THE)', ('NETHERLANDS', 95)),
#  ('NIGER (THE)', ('NIGER', 90)),
#  ('BRUNEI DARUSSALAM', ('BRUNEI', 90)),
#  ('COMOROS (THE)', ('COMOROS', 90)),
#  ('CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#   ('DEMOCRATIC REPUBLIC OF THE CONGO', 95)),
#  ('CENTRAL AFRICAN REPUBLIC (THE)', ('CENTRAL AFRICAN REPUBLIC', 95)),
#  ('GAMBIA (THE)', ('GAMBIA', 90)),
#  ("CÔTE D'IVOIRE", ('IVORY COAST', 58)),
#  ('IRAN (ISLAMIC REPUBLIC OF)', ('IRAN', 90)),
#  ('UNITED STATES OF AMERICA (THE)', ('UNITED STATES', 90)),
#  ('SUDAN (THE)', ('SUDAN', 90)),
#  ('KOREA (THE REPUBLIC OF)', ('SOUTH KOREA', 86)),
#  ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#   ('UNITED KINGDOM', 90)),
#  ('TANZANIA, THE UNITED REPUBLIC OF', ('TANZANIA', 90)),
#  ('CONGO (THE)', ('CONGO', 90)),
#  ('PHILIPPINES (THE)', ('PHILIPPINES', 95)),
#  ('NORTHERN MARIANA ISLANDS (THE)', ('NORTHERN MARIANA ISLANDS (US)', 91)),
#  ('MOLDOVA (THE REPUBLIC OF)', ('MOLDOVA', 90)),
#  ('CABO VERDE', ('CAPE VERDE', 80)),
#  ('MICRONESIA (FEDERATED STATES OF)', ('FEDERATED STATES OF MICRONESIA', 95)),
#  ("LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)", ('CENTRAL AFRICAN REPUBLIC', 86)),
#  ('SAMOA', ('AMERICAN SAMOA (US)', 90)),
#  ('DOMINICAN REPUBLIC (THE)', ('DOMINICAN REPUBLIC', 95)),
#  ('TIMOR-LESTE', ('EAST TIMOR', 81))]

# %% [markdown]
# Each element in the *list* above is in parentheses, for instance:
#
# ```
# ('TIMOR-LESTE', ('EAST TIMOR', 81))
# ```
#
# That element has two elements:
#
#
# *   **'TIMOR-LESTE'** from *onlyDF*, and
# *   **('EAST TIMOR', 81)** which is the result from _best(country,onlyGDF)_. This last element, as we just saw above, shows the best match and the level of similarity (the higher the more similar).
#
# We can prepare a list where each element has three elements:

# %%
[(country, best(country,onlyGDF)[0],best(country,onlyGDF)[1]) for country in onlyDF]
# Out:
# [('BAHAMAS (THE)', 'BAHAMAS', 90),
#  ('BOLIVIA (PLURINATIONAL STATE OF)', 'BOLIVIA', 90),
#  ('UNITED ARAB EMIRATES (THE)', 'UNITED ARAB EMIRATES', 95),
#  ('RUSSIAN FEDERATION (THE)', 'RUSSIA', 90),
#  ('ESWATINI', 'MARTINIQUE (FRANCE)', 60),
#  ('NORTH MACEDONIA', 'MACEDONIA', 90),
#  ('NETHERLANDS (THE)', 'NETHERLANDS', 95),
#  ('NIGER (THE)', 'NIGER', 90),
#  ('BRUNEI DARUSSALAM', 'BRUNEI', 90),
#  ('COMOROS (THE)', 'COMOROS', 90),
#  ('CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#   'DEMOCRATIC REPUBLIC OF THE CONGO',
#   95),
#  ('CENTRAL AFRICAN REPUBLIC (THE)', 'CENTRAL AFRICAN REPUBLIC', 95),
#  ('GAMBIA (THE)', 'GAMBIA', 90),
#  ("CÔTE D'IVOIRE", 'IVORY COAST', 58),
#  ('IRAN (ISLAMIC REPUBLIC OF)', 'IRAN', 90),
#  ('UNITED STATES OF AMERICA (THE)', 'UNITED STATES', 90),
#  ('SUDAN (THE)', 'SUDAN', 90),
#  ('KOREA (THE REPUBLIC OF)', 'SOUTH KOREA', 86),
#  ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#   'UNITED KINGDOM',
#   90),
#  ('TANZANIA, THE UNITED REPUBLIC OF', 'TANZANIA', 90),
#  ('CONGO (THE)', 'CONGO', 90),
#  ('PHILIPPINES (THE)', 'PHILIPPINES', 95),
#  ('NORTHERN MARIANA ISLANDS (THE)', 'NORTHERN MARIANA ISLANDS (US)', 91),
#  ('MOLDOVA (THE REPUBLIC OF)', 'MOLDOVA', 90),
#  ('CABO VERDE', 'CAPE VERDE', 80),
#  ('MICRONESIA (FEDERATED STATES OF)', 'FEDERATED STATES OF MICRONESIA', 95),
#  ("LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)", 'CENTRAL AFRICAN REPUBLIC', 86),
#  ('SAMOA', 'AMERICAN SAMOA (US)', 90),
#  ('DOMINICAN REPUBLIC (THE)', 'DOMINICAN REPUBLIC', 95),
#  ('TIMOR-LESTE', 'EAST TIMOR', 81)]

# %% [markdown]
# For instace, this element has 3 elements:
#
# ```
#  ('IRAN (ISLAMIC REPUBLIC OF)', 'IRAN', 90)
# ```
#
# The level of similarity would guide us to make update (replace) the strings in one of the KEYs, so that the merging process works properly.
#
# Then, it would be better if we have a data frame instead of a list:

# %%
pd.DataFrame([(country, best(country,onlyGDF)[0],best(country,onlyGDF)[1]) for country in onlyDF])
# Out:
#                                                     0  \
# 0                                       BAHAMAS (THE)
# 1                    BOLIVIA (PLURINATIONAL STATE OF)
# 2                          UNITED ARAB EMIRATES (THE)
# 3                            RUSSIAN FEDERATION (THE)
# 4                                            ESWATINI
# 5                                     NORTH MACEDONIA
# 6                                   NETHERLANDS (THE)
# 7                                         NIGER (THE)
# 8                                   BRUNEI DARUSSALAM
# 9                                       COMOROS (THE)
# 10             CONGO (THE DEMOCRATIC REPUBLIC OF THE)
# 11                     CENTRAL AFRICAN REPUBLIC (THE)
# 12                                       GAMBIA (THE)
# 13                                      CÔTE D'IVOIRE
# 14                         IRAN (ISLAMIC REPUBLIC OF)
# 15                     UNITED STATES OF AMERICA (THE)
# 16                                        SUDAN (THE)
# 17                            KOREA (THE REPUBLIC OF)
# 18  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 19                   TANZANIA, THE UNITED REPUBLIC OF
# 20                                        CONGO (THE)
# 21                                  PHILIPPINES (THE)
# 22                     NORTHERN MARIANA ISLANDS (THE)
# 23                          MOLDOVA (THE REPUBLIC OF)
# 24                                         CABO VERDE
# 25                   MICRONESIA (FEDERATED STATES OF)
# 26             LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)
# 27                                              SAMOA
# 28                           DOMINICAN REPUBLIC (THE)
# 29                                        TIMOR-LESTE
#
#                                    1   2
# 0                            BAHAMAS  90
# 1                            BOLIVIA  90
# 2               UNITED ARAB EMIRATES  95
# 3                             RUSSIA  90
# 4                MARTINIQUE (FRANCE)  60
# 5                          MACEDONIA  90
# 6                        NETHERLANDS  95
# 7                              NIGER  90
# 8                             BRUNEI  90
# 9                            COMOROS  90
# 10  DEMOCRATIC REPUBLIC OF THE CONGO  95
# 11          CENTRAL AFRICAN REPUBLIC  95
# 12                            GAMBIA  90
# 13                       IVORY COAST  58
# 14                              IRAN  90
# 15                     UNITED STATES  90
# 16                             SUDAN  90
# 17                       SOUTH KOREA  86
# 18                    UNITED KINGDOM  90
# 19                          TANZANIA  90
# 20                             CONGO  90
# 21                       PHILIPPINES  95
# 22     NORTHERN MARIANA ISLANDS (US)  91
# 23                           MOLDOVA  90
# 24                        CAPE VERDE  80
# 25    FEDERATED STATES OF MICRONESIA  95
# 26          CENTRAL AFRICAN REPUBLIC  86
# 27               AMERICAN SAMOA (US)  90
# 28                DOMINICAN REPUBLIC  95
# 29                        EAST TIMOR  81

# %% [markdown]
# Let's sort by the column '2' (the third):

# %%
pd.DataFrame([(country, best(country,onlyGDF)[0],best(country,onlyGDF)[1]) for country in onlyDF]).sort_values(by=2)
# Out:
#                                                     0  \
# 13                                      CÔTE D'IVOIRE
# 4                                            ESWATINI
# 24                                         CABO VERDE
# 29                                        TIMOR-LESTE
# 26             LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)
# 17                            KOREA (THE REPUBLIC OF)
# 3                            RUSSIAN FEDERATION (THE)
# 0                                       BAHAMAS (THE)
# 14                         IRAN (ISLAMIC REPUBLIC OF)
# 15                     UNITED STATES OF AMERICA (THE)
# 12                                       GAMBIA (THE)
# 9                                       COMOROS (THE)
# 7                                         NIGER (THE)
# 5                                     NORTH MACEDONIA
# 8                                   BRUNEI DARUSSALAM
# 1                    BOLIVIA (PLURINATIONAL STATE OF)
# 23                          MOLDOVA (THE REPUBLIC OF)
# 27                                              SAMOA
# 18  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 19                   TANZANIA, THE UNITED REPUBLIC OF
# 20                                        CONGO (THE)
# 16                                        SUDAN (THE)
# 22                     NORTHERN MARIANA ISLANDS (THE)
# 6                                   NETHERLANDS (THE)
# 10             CONGO (THE DEMOCRATIC REPUBLIC OF THE)
# 11                     CENTRAL AFRICAN REPUBLIC (THE)
# 2                          UNITED ARAB EMIRATES (THE)
# 21                                  PHILIPPINES (THE)
# 25                   MICRONESIA (FEDERATED STATES OF)
# 28                           DOMINICAN REPUBLIC (THE)
#
#                                    1   2
# 13                       IVORY COAST  58
# 4                MARTINIQUE (FRANCE)  60
# 24                        CAPE VERDE  80
# 29                        EAST TIMOR  81
# 26          CENTRAL AFRICAN REPUBLIC  86
# 17                       SOUTH KOREA  86
# 3                             RUSSIA  90
# 0                            BAHAMAS  90
# 14                              IRAN  90
# 15                     UNITED STATES  90
# 12                            GAMBIA  90
# 9                            COMOROS  90
# 7                              NIGER  90
# 5                          MACEDONIA  90
# 8                             BRUNEI  90
# 1                            BOLIVIA  90
# 23                           MOLDOVA  90
# 27               AMERICAN SAMOA (US)  90
# 18                    UNITED KINGDOM  90
# 19                          TANZANIA  90
# 20                             CONGO  90
# 16                             SUDAN  90
# 22     NORTHERN MARIANA ISLANDS (US)  91
# 6                        NETHERLANDS  95
# 10  DEMOCRATIC REPUBLIC OF THE CONGO  95
# 11          CENTRAL AFRICAN REPUBLIC  95
# 2               UNITED ARAB EMIRATES  95
# 21                       PHILIPPINES  95
# 25    FEDERATED STATES OF MICRONESIA  95
# 28                DOMINICAN REPUBLIC  95

# %% [markdown]
# The previous result helps make a plan based on these cases:
# * **ESWATINI** is always a problem, because it is also *SWAZILAND*.
# * **KOREA (THE REPUBLIC OF)** is not _NORTH KOREA_.
# * **LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)** is too long to match *LAOS* (if it exists in the map like that).
# * **SAMOA** is always a problem, because it is also *WESTERN SAMOA*.
#
# Based on this, we should see what our GDF has:

# %%
countries.Country[countries.Country.str.contains('SWAZ|LAO|SAMOA|KORE')]
# Out:
# 9      AMERICAN SAMOA (US)
# 120            NORTH KOREA
# 122            SOUTH KOREA
# 126                   LAOS
# 242          WESTERN SAMOA
# 243              SWAZILAND
# Name: Country, dtype: object

# %% [markdown]
# Then, it makes sense to change those manually (notice the 'replace' uses Python dictionaries):

# %%
# this is a {dictionary}

manualChanges={'SWAZILAND':'ESWATINI',
               'LAOS':"LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
               'SOUTH KOREA':'KOREA (THE REPUBLIC OF)',
               'WESTERN SAMOA':'SAMOA',
              }

countries.replace(to_replace={'Country':manualChanges},inplace=True)

# %% [markdown]
# At this stage, we should recompute the differences:

# %%
# updating
onlyDF=set(someData.Country)- set(countries.Country)
onlyGDF=set(countries.Country)- set(someData.Country)

# %% [markdown]
# An re run this code:

# %%
# keeping high scores

pd.DataFrame([(country, best(country,onlyGDF)[0],best(country,onlyGDF)[1]) for country in onlyDF]).sort_values(2)
# Out:
#                                                     0  \
# 12                                      CÔTE D'IVOIRE
# 22                                         CABO VERDE
# 25                                        TIMOR-LESTE
# 0                                       BAHAMAS (THE)
# 7                                   BRUNEI DARUSSALAM
# 6                                         NIGER (THE)
# 3                            RUSSIAN FEDERATION (THE)
# 1                    BOLIVIA (PLURINATIONAL STATE OF)
# 14                     UNITED STATES OF AMERICA (THE)
# 15                                        SUDAN (THE)
# 13                         IRAN (ISLAMIC REPUBLIC OF)
# 11                                       GAMBIA (THE)
# 16  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 18                                        CONGO (THE)
# 8                                       COMOROS (THE)
# 4                                     NORTH MACEDONIA
# 21                          MOLDOVA (THE REPUBLIC OF)
# 17                   TANZANIA, THE UNITED REPUBLIC OF
# 20                     NORTHERN MARIANA ISLANDS (THE)
# 5                                   NETHERLANDS (THE)
# 9              CONGO (THE DEMOCRATIC REPUBLIC OF THE)
# 10                     CENTRAL AFRICAN REPUBLIC (THE)
# 2                          UNITED ARAB EMIRATES (THE)
# 19                                  PHILIPPINES (THE)
# 23                   MICRONESIA (FEDERATED STATES OF)
# 24                           DOMINICAN REPUBLIC (THE)
#
#                                    1   2
# 12                       IVORY COAST  58
# 22                        CAPE VERDE  80
# 25                        EAST TIMOR  81
# 0                            BAHAMAS  90
# 7                             BRUNEI  90
# 6                              NIGER  90
# 3                             RUSSIA  90
# 1                            BOLIVIA  90
# 14                     UNITED STATES  90
# 15                             SUDAN  90
# 13                              IRAN  90
# 11                            GAMBIA  90
# 16                    UNITED KINGDOM  90
# 18                             CONGO  90
# 8                            COMOROS  90
# 4                          MACEDONIA  90
# 21                           MOLDOVA  90
# 17                          TANZANIA  90
# 20     NORTHERN MARIANA ISLANDS (US)  91
# 5                        NETHERLANDS  95
# 9   DEMOCRATIC REPUBLIC OF THE CONGO  95
# 10          CENTRAL AFRICAN REPUBLIC  95
# 2               UNITED ARAB EMIRATES  95
# 19                       PHILIPPINES  95
# 23    FEDERATED STATES OF MICRONESIA  95
# 24                DOMINICAN REPUBLIC  95

# %% [markdown]
# All this is correct now!
#
# Let's prepare the changes:

# %%
# new {dictionary}
changesToDF={country: best(country,onlyGDF)[0] for country in onlyDF}
changesToDF
# Out:
# {'BAHAMAS (THE)': 'BAHAMAS',
#  'BOLIVIA (PLURINATIONAL STATE OF)': 'BOLIVIA',
#  'UNITED ARAB EMIRATES (THE)': 'UNITED ARAB EMIRATES',
#  'RUSSIAN FEDERATION (THE)': 'RUSSIA',
#  'NORTH MACEDONIA': 'MACEDONIA',
#  'NETHERLANDS (THE)': 'NETHERLANDS',
#  'NIGER (THE)': 'NIGER',
#  'BRUNEI DARUSSALAM': 'BRUNEI',
#  'COMOROS (THE)': 'COMOROS',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)': 'DEMOCRATIC REPUBLIC OF THE CONGO',
#  'CENTRAL AFRICAN REPUBLIC (THE)': 'CENTRAL AFRICAN REPUBLIC',
#  'GAMBIA (THE)': 'GAMBIA',
#  "CÔTE D'IVOIRE": 'IVORY COAST',
#  'IRAN (ISLAMIC REPUBLIC OF)': 'IRAN',
#  'UNITED STATES OF AMERICA (THE)': 'UNITED STATES',
#  'SUDAN (THE)': 'SUDAN',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)': 'UNITED KINGDOM',
#  'TANZANIA, THE UNITED REPUBLIC OF': 'TANZANIA',
#  'CONGO (THE)': 'CONGO',
#  'PHILIPPINES (THE)': 'PHILIPPINES',
#  'NORTHERN MARIANA ISLANDS (THE)': 'NORTHERN MARIANA ISLANDS (US)',
#  'MOLDOVA (THE REPUBLIC OF)': 'MOLDOVA',
#  'CABO VERDE': 'CAPE VERDE',
#  'MICRONESIA (FEDERATED STATES OF)': 'FEDERATED STATES OF MICRONESIA',
#  'DOMINICAN REPUBLIC (THE)': 'DOMINICAN REPUBLIC',
#  'TIMOR-LESTE': 'EAST TIMOR'}

# %%
someData.replace(to_replace={'Country':changesToDF},inplace=True)

# %% [markdown]
# What is left to match?

# %%
# updating
onlyDF=set(someData.Country)- set(countries.Country)
onlyGDF=set(countries.Country)- set(someData.Country)
[(country, best(country,onlyGDF)) for country in onlyDF]
# Out:
# []

# %% [markdown]
# Once you are here, merging can proceed:

# %%
## GDF to the 'left'
theMapAndData=countries.merge(someData, on='Country')
theMapAndData
# Out:
#                  Country                                           geometry  \
# 0    ANTIGUA AND BARBUDA  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 1            AFGHANISTAN  MULTIPOLYGON (((61.27656 35.60725, 61.29638 35...
# 2                ALGERIA  MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# 3             AZERBAIJAN  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# 4                ALBANIA  MULTIPOLYGON (((20.79192 40.43154, 20.78722 40...
# ..                   ...                                                ...
# 167               ZAMBIA  MULTIPOLYGON (((30.21302 -14.98172, 30.21917 -...
# 168             ZIMBABWE  MULTIPOLYGON (((32.48888 -21.34445, 32.46541 -...
# 169          SOUTH SUDAN  MULTIPOLYGON (((34.21807 9.96458, 34.20722 9.9...
# 170            INDONESIA  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
# 171           EAST TIMOR  MULTIPOLYGON (((124.41824 -9.3001, 124.40446 -...
#
#     iso2 iso3                             region  fragility        co2  \
# 0     AG  ATG  CENTRAL AMERICA AND THE CARIBBEAN       54.4     729000
# 1     AF  AFG                         SOUTH ASIA      105.0    7893000
# 2     DZ  DZA                             AFRICA       75.4  151633000
# 3     AZ  AZE                        MIDDLE EAST       73.2   35389000
# 4     AL  ALB                             EUROPE       58.9    3794000
# ..   ...  ...                                ...        ...        ...
# 167   ZM  ZMB                             AFRICA       85.7    6798000
# 168   ZW  ZWE                             AFRICA       99.5    7902000
# 169   SS  SSD                             AFRICA      112.2    1778000
# 170   ID  IDN            EAST AND SOUTHEAST ASIA       70.4  563543000
# 171   TL  TLS            EAST AND SOUTHEAST ASIA       85.5     538000
#
#        sq_km  num_airports  population    mobiles
# 0        443             4      102634     184000
# 1     652230            68    40121552   23000000
# 2    2381740            95    47022473   51500000
# 3      86600            32    10650239   11000000
# 4      28748             3     3107100    2610000
# ..       ...           ...         ...        ...
# 167   752618           120    20799116   21200000
# 168   390757           144    17150352   15000000
# 169   644329            89    12703714    6170000
# 170  1904569           556   281562465  352000000
# 171    14874            11     1506909    1560000
#
# [172 rows x 11 columns]

# %% [markdown]
# And our GDF has social data now!

# %%
theMapAndData.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       172 non-null    object
#  1   geometry      172 non-null    geometry
#  2   iso2          171 non-null    object
#  3   iso3          172 non-null    object
#  4   region        172 non-null    object
#  5   fragility     172 non-null    float64
#  6   co2           172 non-null    int64
#  7   sq_km         172 non-null    int64
#  8   num_airports  172 non-null    int64
#  9   population    172 non-null    int64
#  10  mobiles       172 non-null    int64
# dtypes: float64(1), geometry(1), int64(5), object(4)
# memory usage: 14.9+ KB

# %% [markdown]
# We got the best possible merge. Let's save this file and make it available on GitHub later:

# %%
theMapAndData.to_file("worldindicators.json")
